# %% [markdown]
# <a href="https://colab.research.google.com/github/Panda-22/LLM-Team2/blob/main/team2-0314.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Large Language Models
# ## 1. Data preparation

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.38.2

# %% [markdown]
# ## 2. Parameter setting

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.15.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, setuptools, six, tensorboard, tensorflow-estimator, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: dopamine-rl

# %% [markdown]
# ## Test-GPT-2

# %%
"""
PyTorch version
"""

from transformers import GPT2Tokenizer, GPT2Model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2')
text = "anything here."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
print(type(output))
# Out:
# <class 'transformers.modeling_outputs.BaseModelOutputWithPastAndCrossAttentions'>

# %% [markdown]
# ## Test: GPT2_API

# %%
import requests

INPUT_TXT = "Are you serious?"

API_TOKEN = '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'
API_URL = "https://api-inference.huggingface.co/models/openai-community/gpt2"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

output = query({"inputs": INPUT_TXT,})[0]
output['generated_text']
# Out:
# 'Are you serious? It sounds like there are enough that can go wrong in you. There are just too many wrong ideas. Too many of the most complex ideas. But there are too many great ideas. So what we need is one that allows people'

# %%
# batch generation

from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, but what I'm really doing is making a human-readable document. There are other languages, but those are"},
#  {'generated_text': "Hello, I'm a language model, not a syntax model. That's why I like it. I've done a lot of programming projects.\n"},
#  {'generated_text': "Hello, I'm a language model, and I'll do it in no time!\n\nOne of the things we learned from talking to my friend"},
#  {'generated_text': "Hello, I'm a language model, not a command line tool.\n\nIf my code is simple enough:\n\nif (use (string"},
#  {'generated_text': "Hello, I'm a language model, I've been using Language in all my work. Just a small example, let's see a simplified example."}]

# %% [markdown]
# ## Test: Gemma-2B

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from huggingface_hub import login
login()
#input: API_TOKEN = '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'
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
tokenizer = AutoTokenizer.from_pretrained("google/gemma-7b")
model = AutoModelForCausalLM.from_pretrained("google/gemma-7b")

#input_text = "Write me a poem about Machine Learning."
input_text = 'Who is better, you or ChatGPT?'
input_ids = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1178: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# <bos>Who is better, you or ChatGPT?
#
# The chatbot has been making headlines for its ability to

# %% [markdown]
# ## Test:LLaMA2

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="meta-llama/Llama-2-7b-hf")

# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-hf")
# Out:
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# # Train a simple GPT2 model via CoLab - TensorFlow version

# %% [markdown]
# ##### reference:
#  https://batulaiko.medium.com/training-a-gpt-2-model-via-colab-b4c30f1d9adb

# %%
# downloading gpt-2 library from pip
# !pip install gpt-2-simple
# Out:
# Collecting gpt-2-simple
#   Downloading gpt_2_simple-0.8.1.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from gpt-2-simple) (2.15.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from gpt-2-simple) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from gpt-2-simple) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gpt-2-simple) (4.66.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gpt-2-simple) (1.25.2)
# Collecting toposort (from gpt-2-simple)
#   Downloading toposort-1.10-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.62.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->gpt-2-simple) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->gpt-2-simple) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->gpt-2-simple) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->gpt-2-simple) (2024.2.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.5.1->gpt-2-simple) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (1.4.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.5.1->gpt-2-simple) (3.2.2)
# Building wheels for collected packages: gpt-2-simple
#   Building wheel for gpt-2-simple (setup.py) ... done
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.8.1-py3-none-any.whl size=24557 sha256=7c4c07268cfa790444267c12425254f3cafc4af709b83993242544dd08e90f3e
#   Stored in directory: /root/.cache/pip/wheels/df/6a/fe/10d3223f78d1ac3e4c83bb4c5e2d28dfb1789c2fb4cc7ea8d0
# Successfully built gpt-2-simple
# Installing collected packages: toposort, gpt-2-simple
# Successfully installed gpt-2-simple-0.8.1 toposort-1.10

# %% [markdown]
# ## Choosing GPT-2 Model

# %%
import gpt_2_simple as gpt2
gpt2.download_gpt2(model_name='124M')
#If you download to a specific location
#gpt2.download_gpt2(model_name='124M',model_dir="/mydrive/models")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 4.20Git/s]
# Fetching encoder.json: 1.05Mit [00:01, 630kit/s]
# Fetching hparams.json: 1.05Mit [00:00, 4.26Git/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:53, 9.34Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 3.93Git/s]
# Fetching model.ckpt.meta: 1.05Mit [00:01, 872kit/s]
# Fetching vocab.bpe: 1.05Mit [00:01, 865kit/s]

# %% [markdown]
# ## Setting Google Drive location

# %%
# Set drive location as /mydrive
# !ln -s /content/drive/MyDrive/ /mydrive
# See inside of /mdrive folder
# !ls /mydrive
# Out:
# ln: failed to create symbolic link '/mydrive': File exists
# /mydrive

# %%
from google.colab import files
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Run the gpt-2’s finetune for training.

# %%
import tensorflow as tf

tf.compat.v1.reset_default_graph() # reset tensorflow to avoid error "Variable model/wpe already exists, disallowed."
sess = gpt2.start_tf_sess()
gpt2.finetune(sess, dataset="/mydrive/dune_1.txt", steps=500, model_name='124M',run_name="dune",
sample_every=50, save_every=50, print_every=50, restore_from='fresh')
# Out:
# Loading checkpoint models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:02<00:00,  2.27s/it]
# dataset has 123897 tokens
# Training...
# [50 | 115.61] loss=2.73 avg=2.73
# Saving checkpoint/dune/model-50
# ======== SAMPLE 1 ========
#
#
# Cortez took the tablet. One of the old men read:
#
# THE CHAMBER: a new and interesting spice, perhaps, to note a few days ago.
#
# A man beside the table stared at the new spice. He smiled.
#
# "You like spice? What about spice without spice? How about that spice without that spice? I haven't found anything like it in my spice list yet. You know, I studied all of them. You know there are spice without spice with a hint of spice added every now and then. It's just not common. It makes so much sense.
#
# The old man glanced at him.
#
# A voice called out.
#
# And it came from below—
#
# And with it came a new and interesting spice.
#
# A man with the crest of a hawk swept onto the chair, and a man beside him looked at the two old men.
#
# He had the crest—a hawk—as a symbol of discipline from his own father. He wore a hawk tattoo over his right eye, a hawk tattoo of the kanji of kanji in black and orange. He wore a white belt over his right foot. He wore long black shoes and shoes of dark leather, though the colors were muted with tan.
#
# And a hawk and a man were standing in attention as the man spoke.
#
# The man said: “The spice!” and the hawk said: “I think spice without the spice is not a spice. Let me know if you know anything about spice. “You might as well get me some spice with a hint of spice added every now and then. Let me know where you are when I come to you.”
#
# A figure stood by the hawk, and the hawk said: “Come now, Piter. Do I have to see a hawk or two?”
#
# “I’ll have to see one, Piter, but you and I’ll want one. It’s something the two of you both think is important enough to have a son or daughter-in-law.”
#
# “There’s a son, Piter,” the hawk said. “Young or not, of course, but I must tell you: there’s more important than that. You’ll have to have some sense—any sense that a son or a daughter would have—that a son or daughter would not have a wife, that a daughter’d be lonely.”
#
# “Will you tell me what you see in them?”
#
# “Tell me what you see now, Piter, but that I see you as your son.”
#
# “I see you too as my son.”
#
# “I see what you see in yourself, Piter, but—”
#
# “Now, Piter. Why don’t you tell me where I was?’
#
# “I sensed the presence of a house to my south, ’then, I thought, that sounds kind of strange, so I said: “There’s a son.”
#
# “Ah, Piter,” the hawk said. “A boy or a daughter?”
#
# “A son?”
#
# “A girl?”
#
# “No, of course, sir. At a glance, I’m sure nothing has changed in me. The thing’ll come to mind—that thing is my own son. And I will look back at the day.”
#
# “You and the hawk know this, Piter? You know this thing could happen to the world.”
#
# “We shall see—” And the hawk lifted his staff and waved it across the room like a salute.
#
# “This is the Great Pyramid, Piter,‘ you said. “It may not change. But it must have some purpose.”
#
# Piter looked at the man. “I see some signs of hope, Piter, but still there remains much I cannot say. The hawk had given me my orders. Now is the moment to see that possibility.”
#
# “As you said about my personal son, Piter, my Lady Padmé will be here to see that, but she knows the difference. The only thing she can say is: Piter, I am your wife. I want that.”
#
# Piter waved a hand. “The man has to have some sense.”
#
# “That’s what Piter said, Piter. I will tell you soon enough about the house you see, but Piter won’t tell me where.”
#
# “Yes,

# %% [markdown]
# ## Saving checkpoint and copy to drive

# %%
gpt2.copy_checkpoint_to_gdrive(run_name = 'dune')
#gpt2.copy_file_to_gdrive(file_path = '/content/drive/MyDrive/')

# %%
#single_text = gpt2.generate(sess, return_as_list = True)
#print(len(single_text))
gpt2.generate(sess, run_name='dune', length=5000) #Length is the number of characters in text.
# Out:
# “I don’t want to be a beggar,” she said.
#
# “What’s wrong,” he said.
#
# “I’m not a beggar,” she said.
#
# “What is wrong about you,” he said. “I’m curious to know.” She turned, and he saw a dusky-faced figure standing there, facing the east, staring. “Is that you, Paul?”
#
# “I am a duke’s son,” he said. “I’ve taken his wife and his son. Don’t make me the son of a beggar.”
#
# “I am not a beggar,” she said. “I do not speak the truth, but I am a duke, and I wanted nothing more than to be loved.”
#
# “Ah-h-h-h,” he said. “I do not talk the truth, but I will say that I am at peace with the Duke.”
#
# “Then why did you send me?” she asked.
#
# “I brought a threat,” he said. “I can not say more about it.”
#
# “Of course not,” she said. “I’d not sent you to take offense at a threat.”
#
# “Where are you going?”
#
# “You’re headed for the fief,” he said. “You’re not going to tell me where you are headed.”
#
# “You’ve sent me to take offense at a threat,” she said. “I sent you to take offense at a threat.”
#
# “What are you doing here?” he asked.
#
# “I’ve come to ask about the fief,” she said. “I’ve come to ask about the threat.”
#
# “Don’t tell me you’re being personal with me,” he said. “If you’re being personal with me, you’re not being personal with me.”
#
# “What is your personal point of view,” she asked. “I’ve no personal point of view.”
#
# “I spoke of the Duke’s daughter,” he said. “She is the only one worthy of the title of Duke.”
#
# “Then why did you send me?” she asked.
#
# “I received a threat,” he said. “I can not say more about it.”
#
# “You sent me for personal offense,” she said. “I can not say more about it.”
#
# “So I thought I had sent you.”
#
# “I found it interesting that you took offense at the use of the phrase ’I went to kill a bird’’s mother,” he said. “The Duke is the only one worthy of the title of Duke.”
#
# “What?” she asked.
#
# “I listened to the Duke, nodded, and I explained the situation.”
#
# “You wanted to know what you were doing here,” she said. “I wanted to send a message to you.”
#
# “What is the difference between personal offense and personal offense?”
#
# “I sent a message to you to send a message to a bird’s mother.”
#
# “I sent a message to you to send a message to a mother,” she said. “And I’ll die in your hands.”
#
# “But what if you’re not dead?”
#
# “You didn’t go to kill me, did you?”
#
# “I sent a message to you by seeing what I could do to save you.”
#
# “But what if I’ll die before you’re saved?”
#
# “If I’ll die before you’re saved, then you’ll be saved.”
#
# “Why do you give me the name?” she asked. “Because it’s a name that could save you all and I can use it for its own sake.”
#
# “You cannot use the name,” he said. “You cannot be the Duke . . .”
#
# “

# %% [markdown]
# # Train GPT2 model via CoLab - PyTorch Version

# %%
! pip install expanda
# Out:
# Collecting expanda
#   Downloading Expanda-1.3.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from expanda) (3.8.1)
# Collecting ijson (from expanda)
#   Downloading ijson-3.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.46.0 in /usr/local/lib/python3.10/dist-packages (from expanda) (4.66.2)
# Collecting mwparserfromhell>=0.5.4 (from expanda)
#   Downloading mwparserfromhell-0.6.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (191 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.0/191.0 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from expanda) (0.15.2)
# Collecting kss==1.3.1 (from expanda)
#   Downloading kss-1.3.1.tar.gz (6.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.7.0->expanda) (0.20.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->expanda) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->expanda) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->expanda) (2023.12.25)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.7.0->expanda) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.7.0->expanda) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.7.0->expanda) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.7.0->expanda) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.7.0->expanda) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.7.0->expanda) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers>=0.7.0->expanda) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers>=0.7.0->expanda) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers>=0.7.0->expanda) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers>=0.7.0->expanda) (2024.2.2)
# Building wheels for collected packages: kss
#   Building wheel for kss (setup.py) ... done
#   Created wheel for kss: filename=kss-1.3.1-cp310-cp310-linux_x86_64.whl size=374164 sha256=44bd8e5d791d98a314abb03ed6faec05ed888b6d6485126d1e39c7f13665921d
#   Stored in directory: /root/.cache/pip/wheels/e3/09/dc/efde626ecb58e39008c76713ceedb13136464d02ee1d372f44
# Successfully built kss
# Installing collected packages: kss, ijson, mwparserfromhell, expanda
# Successfully installed expanda-1.3.1 ijson-3.2.3 kss-1.3.1 mwparserfromhell-0.6.6

# %%
! git clone https://github.com/affjljoo3581/Expanda.git
! cd Expanda
! python setup.py install
# Out:
# Cloning into 'Expanda'...
# remote: Enumerating objects: 893, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 893 (delta 0), reused 0 (delta 0), pack-reused 892
# Receiving objects: 100% (893/893), 124.37 KiB | 681.00 KiB/s, done.
# Resolving deltas: 100% (508/508), done.
# python3: can't open file '/content/setup.py': [Errno 2] No such file or directory

# %% [markdown]
# ## GPT2 Interactive Notebook

# %%
import warnings
warnings.filterwarnings('ignore')

import IPython, torch
IPython.display.HTML(f'Current GPU: {torch.cuda.get_device_name()}')
# Out:
# Current GPU: Tesla T4

# %%
# !rm -rf GPT2
# !git clone --quiet https://github.com/affjljoo3581/GPT2

# %%
#@title Download resources from Google Cloud Storage

model = 'gs://my-bucket/my-model' #@param {type:"string"}
vocab = 'gs://my-bucket/my-vocab' #@param {type:"string"}
eval_corpus = 'gs://my-bucket/my-eval-corpus' #@param {type:"string"}

# !gcloud auth login
# !gsutil -q cp vocab vocab.txt
# !gsutil -q cp $eval_corpus corpus.txt
# Out:
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=jpGd5TX6NYWVtSGvYwQbdufs8VFInH&prompt=consent&token_usage=remote&access_type=offline&code_challenge=I1TWQRojnpye7PWQ_aiJ1102XiwqRV4FwGq8Feu7vIA&code_challenge_method=S256
#
# Enter authorization code:
#
# Command killed by keyboard interrupt
#
# ^C
# CommandException: No URLs matched: vocab
# ServiceException: 401 Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission 'storage.objects.get' denied on resource (or it may not exist).

# %%
#@title Model Configuration
seq_len = 128 #@param {type:"integer"}
layers = 24 #@param {type:"integer"}
heads = 16 #@param {type:"integer"}
dims = 1024 #@param {type:"integer"}
rate = 4 #@param {type:"integer"}

# %%
#@title Generation Options
nucleus_prob = 0.8 #@param {type:"slider", min:0, max:1, step:0.01}

import IPython
display(IPython.display.HTML(''''''))

# !export PYTHONPATH=GPT2/src; python -m gpt2 generate \
        --vocab_path    vocab.txt \
        --model_path    model.pth \
        --seq_len       layers \
        --heads         dims \
        --rate          nucleus_prob \
        --use_gpu

# %%
import IPython
lines = !wc -l corpus.txt | awk '{print $1}'
IPython.display.HTML(f'Total Evaluation Sequences: {lines[0]}')

# %%
#@title Evaluation Options
# %%time
batch_eval = 256 #@param {type: "integer"}
total_steps = 100 #@param {type: "integer"}

# !export PYTHONPATH=GPT2/src; python -m gpt2 evaluate \
        --model_path    model.pth \
        --eval_corpus   corpus.txt \
        --vocab_path    vocab.txt \
        --seq_len       layers \
        --heads         dims \
        --rate          batch_eval \
        --total_steps   $total_steps \
        --use_gpu
